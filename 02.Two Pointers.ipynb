# %% [markdown]
# # 02 Two Pointers
#
# ## Problem List
#
# | #  | Problem Name                          | Difficulty | LeetCode ID                                               |
# |----|---------------------------------------|------------|------------------------------------------------------------|
# | 1  | [Reverse String](#reverse-string)                        | Easy       | [LC0344](https://leetcode.com/problems/reverse-string/)                |
# | 2  | [Valid Palindrome](#valid-palindrome)                    | Easy       | [LC0125](https://leetcode.com/problems/valid-palindrome/)             |
# | 3  | [Valid Palindrome II](#valid-palindrome-ii)              | Easy       | [LC0680](https://leetcode.com/problems/valid-palindrome-ii/)          |
# | 4  | [Merge Strings Alternately](#merge-strings-alternately)  | Easy       | [LC1768](https://leetcode.com/problems/merge-strings-alternately/)    |
# | 5  | [Merge Sorted Array](#merge-sorted-array)                | Easy       | [LC0088](https://leetcode.com/problems/merge-sorted-array/)           |
# | 6  | [Remove Duplicates From Sorted Array](#remove-duplicates-from-sorted-array) | Easy | [LC0026](https://leetcode.com/problems/remove-duplicates-from-sorted-array/) |
# | 7  | [Two Sum II – Input Array Is Sorted](#two-sum-ii-input-array-is-sorted) | Medium | [LC0167](https://leetcode.com/problems/two-sum-ii-input-array-is-sorted/)   |
# | 8  | [3Sum](#3sum)                                            | Medium     | [LC0015](https://leetcode.com/problems/3sum/)                         |
# | 9  | [4Sum](#4sum)                                            | Medium     | [LC0018](https://leetcode.com/problems/4sum/)                         |
# | 10 | [Rotate Array](#rotate-array)                            | Medium     | [LC0189](https://leetcode.com/problems/rotate-array/)                 |
# | 11 | [Container With Most Water](#container-with-most-water)  | Medium     | [LC0011](https://leetcode.com/problems/container-with-most-water/)    |
# | 12 | [Boats to Save People](#boats-to-save-people)            | Medium     | [LC0881](https://leetcode.com/problems/boats-to-save-people/)         |
# | 13 | [Trapping Rain Water](#trapping-rain-water)              | Hard       | [LC0042](https://leetcode.com/problems/trapping-rain-water/)          |

# %% [markdown]
# ### <a name="reverse-string"></a>Reverse String
#
#
# **Problem**
# You are given an array of characters which represents a string `s`. Write a function which reverses the string.
#
# You must do this by modifying the input array **in-place** with **O(1)** extra memory.
#
# **Example:**
# Input:  `s = ["n","e","e","t"]`
# Output: `["t","e","e","n"]`

# %%
class Solution:
    def reverseString(self, s: List[str]) -> None:
        """
        Do not return anything, modify s in-place instead.
        """
        l = 0
        value = len(s)
        half = len(s)//2

        while l < half: 
            s.insert(value, s[l])
            last = s.pop(value-1)
            s[l] = last
            
            l += 1
            value -= 1

### in place replacement
        
    def reverse(l, r):
            if l < r:
                reverse(l + 1, r - 1)
                s[l], s[r] = s[r], s[l]
        
        reverse(0, len(s) - 1)

# %% [markdown]
# ### <a name="valid-palindrome"></a>Valid Palindrome
#
# **Problem 2**
# Given a string `s`, return `true` if it is a palindrome, otherwise return `false`.
#
# A palindrome is a string that reads the same forward and backward. It is also case-insensitive and ignores all non-alphanumeric characters.
#
# **Note:** Alphanumeric characters consist of letters (A–Z, a–z) and numbers (0–9).
#
# **Example:**
# Input:  `s = "Was it a car or a cat I saw?"`
# Output: `true`
# **Explanation:**  After considering only alphanumerical characters, we have `"wasitacaroracatisaw"`, which is a palindrome.

# %%
class Solution:
    def isPalindrome(self, s: str) -> bool:
        newStr = ''
        for c in s:
            if c.isalnum():
                newStr += c.lower()
        
        return newStr == newStr[::-1]

# %% [markdown]
# ### <a name="valid-palindrome-ii"></a>Valid Palindrome II
#
# **Problem 3**
# You are given a string `s`, return `true` if `s` can be a palindrome after deleting at most one character from it.
#
# A palindrome is a string that reads the same forward and backward.
#
# **Note:** Alphanumeric characters consist of letters (A–Z, a–z) and numbers (0–9).
#
# **Example:**
# Input:  `s = "abbadc"`
# Output:  `false`
# **Explanation:**  "abbadc" is not a palindrome and cannot be made into one by deleting just one character.

# %%
class Solution:
    def validPalindrome(self, s: str) -> bool:
        def is_palindrome(s):
            i, j = 0, len(s)-1
            while i < j:
                if s[i] != s[j]:
                    return False
                i +=1
                j -=1
            return True

        l, r = 0, len(s)-1
        while l < r:
            if s[l] != s[r]:
                return (is_palindrome(s[l+1:r+1]) or 
                        is_palindrome(s[l:r]))
            l +=1
            r -=1
        return True

# %% [markdown]
# ### <a name="merge-strings-alternately"></a>Merge Strings Alternately
#
# **Problem 4**
# You are given two strings, `word1` and `word2`. Construct a new string by merging them in alternating order, starting with `word1` — take one character from `word1`, then one from `word2`, and repeat this process.
#
# If one string is longer than the other, append the remaining characters from the longer string to the end of the merged result.
#
# Return the final merged string.
#
# **Example:**
# Input:  `word1 = "abc", word2 = "xyz"`
# Output: `"axbycz"`

# %%
class Solution:
    def mergeAlternately(self, word1: str, word2: str) -> str:
        l1, l2 = 0, 0
        s = ""
        while l1 < len(word1) and l2 < len(word2):
            s += word1[l1]
            s += word2[l2]
            l1 += 1
            l2 += 1
        s += word1[l1:]
        s += word2[l2:]
        
        return s

# %% [markdown]
# ### <a name="merge-sorted-array"></a>Merge Sorted Array
#
# **Problem 5**
# You are given two integer arrays `nums1` and `nums2`, both sorted in non-decreasing order, along with two integers `m` and `n`, where:
#
# - `m` is the number of valid elements in `nums1`,
# - `n` is the number of elements in `nums2`.
#
# The array `nums1` has a total length of `m + n`, with the first `m` elements containing the values to be merged, and the last `n` elements set to `0` as placeholders.
#
# Your task is to merge the two arrays such that the final merged array is also sorted in non-decreasing order and stored entirely within `nums1`.
# You must **modify `nums1` in-place** and **do not return anything** from the function.
#
# **Example:**
# Input:  `nums1 = [10,20,20,40,0,0], m = 4` & `nums2 = [1,2], n = 2`
# Output:  `[1,2,10,20,20,40]`

# %%
class Solution:
    def merge(self, nums1: List[int], m: int, nums2: List[int], n: int) -> None:
        """
        Do not return anything, modify nums1 in-place instead.
        """
        last = m + n - 1

        while m > 0 and n > 0:
            if nums1[m-1] >= nums2[n-1]:
                nums1[last] = nums1[m-1]
                m -= 1
            else:
                nums1[last] = nums2[n-1]
                n -= 1
            last -= 1
        
        while n > 0:
            nums1[n-1] = nums2[n-1]
            n -= 1

# %% [markdown]
# ### <a name="remove-duplicates-from-sorted-array"></a>Remove Duplicates From Sorted Array
#
# **Problem 6**
# You are given an integer array `nums` sorted in non-decreasing order. Your task is to remove duplicates from `nums` **in-place** so that each element appears only once.
#
# After removing the duplicates, return the number of unique elements, denoted as `k`, such that the first `k` elements of `nums` contain the unique elements.
#
# **Note:**
# - The order of the unique elements should remain the same as in the original array.
# - It is not necessary to consider elements beyond the first `k` positions of the array.
# - To be accepted, the first `k` elements of `nums` must contain all the unique elements.
# - Return `k` as the final result.
#
# **Example:**
# Input: `nums = [1,1,2,3,4]`
# Output: `4`, `nums = [1,2,3,4,...]`
# **Explanation**: You should return `k = 4` as we have four unique elements.

# %%
class Solution:
    def removeDuplicates(self, nums: List[int]) -> int:
        L = 0
        for i in range(L+1, len(nums)):
            if nums[i] != nums[L]:
                L += 1
                nums[L] = nums[i]
        
        return L+1

# %% [markdown]
# ### <a name="two-sum-ii-input-array-is-sorted"></a>Two Sum II – Input Array Is Sorted
# ### <a name="3sum"></a>3Sum
# ### <a name="4sum"></a>4Sum
# ### <a name="rotate-array"></a>Rotate Array
# ### <a name="container-with-most-water"></a>Container With Most Water
# ### <a name="boats-to-save-people"></a>Boats to Save People
# ### <a name="trapping-rain-water"></a>Trapping Rain Water
